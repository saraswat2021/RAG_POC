# %% [markdown]
# ### Building a RAG System with LangChain and FAISS
# Introduction to RAG (Retrieval-Augmented Generation)
# RAG combines the power of retrieval systems with generative AI models. Instead of relying solely on the model's training data, RAG:
#
# 1. Retrieves relevant documents from a knowledge base
# 2. Uses these documents as context for the LLM
# 3. Generates responses based on both the retrieved context and the model's knowledge
#
# ### FAISS
# https://github.com/facebookresearch/faiss
#
# FAISS is a library for efficient similarity search and clustering of dense vectors.
#
# Key advantages:
# 1. Extremely fast similarity search
# 2. Memory efficient
# 3. Supports GPU acceleration
# 4. Can handle millions of vectors
#
# How it works:
# - Indexes vectors for fast nearest neighbor search
# - Returns most similar vectors based on distance metrics

# %%
from langchain_core.documents import Document

sample_documents = [
    Document(
        page_content="""
        Artificial Intelligence (AI) is the simulation of human intelligence in machines.
        These systems are designed to think like humans and mimic their actions.
        AI can be categorized into narrow AI and general AI.
        """,
        metadata={"source": "AI Introduction", "page": 1, "topic": "AI"}
    ),
    Document(
        page_content="""
        Machine Learning is a subset of AI that enables systems to learn from data.
        Instead of being explicitly programmed, ML algorithms find patterns in data.
        Common types include supervised, unsupervised, and reinforcement learning.
        """,
        metadata={"source": "ML Basics", "page": 1, "topic": "ML"}
    ),
    Document(
        page_content="""
        Deep Learning is a subset of machine learning based on artificial neural networks.
        It uses multiple layers to progressively extract higher-level features from raw input.
        Deep learning has revolutionized computer vision, NLP, and speech recognition.
        """,
        metadata={"source": "Deep Learning", "page": 1, "topic": "DL"}
    ),
    Document(
        page_content="""
        Natural Language Processing (NLP) is a branch of AI that helps computers understand human language.
        It combines computational linguistics with machine learning and deep learning models.
        Applications include chatbots, translation, sentiment analysis, and text summarization.
        """,
        metadata={"source": "NLP Overview", "page": 1, "topic": "NLP"}
    )
]

print(f"size of documents {len(sample_documents)}")
# Out:
# size of documents 4

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 30,
    separators=["/n", " "]
)
splitted_chunks = splitter.split_documents(sample_documents)
print(splitted_chunks)
print(f"Size of chunks {len(splitted_chunks)}")
# Out:
# [Document(metadata={'source': 'AI Introduction', 'page': 1, 'topic': 'AI'}, page_content='Artificial Intelligence (AI) is the simulation of human intelligence in machines.'), Document(metadata={'source': 'AI Introduction', 'page': 1, 'topic': 'AI'}, page_content='in machines.\n        These systems are designed to think like humans and mimic their actions.'), Document(metadata={'source': 'AI Introduction', 'page': 1, 'topic': 'AI'}, page_content='mimic their actions.\n        AI can be categorized into narrow AI and general AI.'), Document(metadata={'source': 'ML Basics', 'page': 1, 'topic': 'ML'}, page_content='Machine Learning is a subset of AI that enables systems to learn from data.\n        Instead'), Document(metadata={'source': 'ML Basics', 'page': 1, 'topic': 'ML'}, page_content='from data.\n        Instead of being explicitly programmed, ML algorithms find patterns in data.'), Document(metadata={'source': 'ML Basics', 'page': 1, 'topic': 'ML'}, page_content='find patterns in data.\n        Common types include supervised, unsupervised, and reinforcement'), Document(metadata={'source': 'ML Basics', 'page': 1, 'topic': 'ML'}, page_content='and reinforcement learning.'), Document(metadata={'source': 'Deep Learning', 'page': 1, 'topic': 'DL'}, page_content='Deep Learning is a subset of machine learning based on artificial neural networks.'), Document(metadata={'source': 'Deep Learning', 'page': 1, 'topic': 'DL'}, page_content='neural networks.\n        It uses multiple layers to progressively extract higher-level features'), Document(metadata={'source': 'Deep Learning', 'page': 1, 'topic': 'DL'}, page_content='extract higher-level features from raw input.\n        Deep learning has revolutionized computer'), Document(metadata={'source': 'Deep Learning', 'page': 1, 'topic': 'DL'}, page_content='has revolutionized computer vision, NLP, and speech recognition.'), Document(metadata={'source': 'NLP Overview', 'page': 1, 'topic': 'NLP'}, page_content='Natural Language Processing (NLP) is a branch of AI that helps computers understand human'), Document(metadata={'source': 'NLP Overview', 'page': 1, 'topic': 'NLP'}, page_content='computers understand human language.\n        It combines computational linguistics with machine'), Document(metadata={'source': 'NLP Overview', 'page': 1, 'topic': 'NLP'}, page_content='linguistics with machine learning and deep learning models.\n        Applications include chatbots,'), Document(metadata={'source': 'NLP Overview', 'page': 1, 'topic': 'NLP'}, page_content='include chatbots, translation, sentiment analysis, and text summarization.')]
# Size of chunks 15

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(
    "google/embeddinggemma-300m",
    token="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"
    )
embedding_model
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 2048, 'do_lower_case': False, 'architecture': 'Gemma3TextModel'})
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Dense({'in_features': 768, 'out_features': 3072, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (3): Dense({'in_features': 3072, 'out_features': 768, 'bias': False, 'activation_function': 'torch.nn.modules.linear.Identity'})
#   (4): Normalize()
# )

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 embeddings = []
#       2 for chunk in splitted_chunks:
# ----> 3     result = embedding_model.get_sentence_embedding_dimension(chunk)
#       4     result
#
# TypeError: SentenceTransformer.get_sentence_embedding_dimension() takes 1 positional argument but 2 were given

# %% [markdown]
# ### Create FAISS Vector Store

# %%
from langchain_community.vectorstores import FAISS
faiss_vector_store = FAISS.(
    documents=splitted_chunks,
    embedding=embedding_model
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 from langchain_community.vectorstores import FAISS
# ----> 2 faiss_vector_store = FAISS.from_documents(
#       3     documents=splitted_chunks,
#       4     embedding=embedding_model
#       5 )
#
# File c:\Users\sumsaras\Documents\PersonalWorkspace\AI_Learning\RAG\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Users\sumsaras\Documents\PersonalWorkspace\AI_Learning\RAG\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)   1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)   1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)   1050         **kwargs,
#    1051     )
#
# File c:\Users\sumsaras\Documents\PersonalWorkspace\AI_Learning\RAG\.venv\Lib\site-packages\torch\nn\modules\module.py:1965, in Module.__getattr__(self, name)
#    1963     if name in modules:
#    1964         return modules[name]
# -> 1965 raise AttributeError(
#    1966     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1967 )
#
# AttributeError: 'SentenceTransformer' object has no attribute 'embed_documents'
